# %% [markdown]
# # Project 4: Data Visualization

# %%
# To import my libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1. Bar Chart: Total Sales by Product
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='Product', y='TotalPrice', estimator=sum, ci=None, 
            order=df.groupby('Product')['TotalPrice'].sum().sort_values(ascending=False).index)
plt.title('Total Sales by Product')
plt.xlabel('Product')
plt.ylabel('Total Sales ($)')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_23728\3003412822.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x='Product', y='TotalPrice', estimator=sum, ci=None,

# %%
df['Date'] = pd.to_datetime(df['Date'])

# 2. Extracted the Year-Month from the date
df['MonthYear'] = df['Date'].dt.to_period('M').astype(str)
monthly_sales = df.groupby('MonthYear')['TotalPrice'].sum().reset_index()

# 3. Ploted the Line Chart
plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly_sales, x='MonthYear', y='TotalPrice', marker='o')
plt.title('Monthly Sales Trend')
plt.xlabel('Month-Year')
plt.ylabel('Total Sales ($)')
plt.xticks(rotation=90)
plt.show()

# %%
# 3. Pie Chart: Order Status Distribution
status_counts = df['OrderStatus'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Order Status Distribution')
plt.show()
